# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitute & longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combinations.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API call.
# Create an endpoint URL for a city.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descrip = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | iquitos
# Processing Record 5 of Set 1 | fez
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | balaipungut
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | abu kamal
# Processing Record 12 of Set 1 | leua
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | port lincoln
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | mae ramat
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | port macquarie
# Processing Record 24 of Set 1 | sars
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | fonte boa
# Processing Record 27 of Set 1 | khovu-aksy
# Processing Record 28 of Set 1 | kieta
# Processing Record 29 of Set 1 | likasi
# Processing Record 30 of Set 1 | peniche
# Processing Record 31 of Set 1 | komsomolskiy
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 1 | parfino
# Processing Record 35 of Set 1 | yakeshi
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | pacific grove
# Processing Record 39 of Set 1 | manzhouli
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | acqui terme
# Processing Record 42 of Set 1 | lincoln
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | mount gambier
# Processing Record 45 of Set 1 | sao joao da barra
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | kirakira
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | northam
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | ambon
# Processing Record 7 of Set 2 | malakal
# Processing Record 8 of Set 2 | santa vitoria
# Processing Record 9 of Set 2 | asau
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | vao
# Processing Record 12 of Set 2 | pochutla
# Processing Record 13 of Set 2 | gizo
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | nouadhibou
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | yerbogachen
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | kaitangata
# Processing Record 23 of Set 2 | bandarbeyla
# Processing Record 24 of Set 2 | hamilton
# Processing Record 25 of Set 2 | rio claro
# Processing Record 26 of Set 2 | sainte-marie
# Processing Record 27 of Set 2 | namatanai
# Processing Record 28 of Set 2 | addis abeba
# Processing Record 29 of Set 2 | fort saint james
# Processing Record 30 of Set 2 | buchanan
# Processing Record 31 of Set 2 | zuenoula
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | san bartolome de tirajana
# Processing Record 34 of Set 2 | dalbandin
# Processing Record 35 of Set 2 | filadelfia
# Processing Record 36 of Set 2 | yaan
# Processing Record 37 of Set 2 | athabasca
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | benghazi
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | newton
# Processing Record 43 of Set 2 | laguna
# Processing Record 44 of Set 2 | pundaguitan
# Processing Record 45 of Set 2 | savannah bight
# Processing Record 46 of Set 2 | margate
# Processing Record 47 of Set 2 | privolzhsk
# Processing Record 48 of Set 2 | necochea
# Processing Record 49 of Set 2 | saint-francois
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 3 | carutapera
# Processing Record 4 of Set 3 | laiyang
# Processing Record 5 of Set 3 | xingtai
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | constitucion
# Processing Record 9 of Set 3 | inta
# Processing Record 10 of Set 3 | kavieng
# Processing Record 11 of Set 3 | sambava
# Processing Record 12 of Set 3 | kalga
# Processing Record 13 of Set 3 | yanam
# Processing Record 14 of Set 3 | dondo
# Processing Record 15 of Set 3 | la ronge
# Processing Record 16 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | tara
# Processing Record 20 of Set 3 | vaini
# Processing Record 21 of Set 3 | mayumba
# Processing Record 22 of Set 3 | mandalgovi
# Processing Record 23 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | sarkand
# Processing Record 27 of Set 3 | russell
# Processing Record 28 of Set 3 | taucha
# Processing Record 29 of Set 3 | yeppoon
# Processing Record 30 of Set 3 | narsaq
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | port blair
# Processing Record 34 of Set 3 | novyy urgal
# Processing Record 35 of Set 3 | khatanga
# Processing Record 36 of Set 3 | fukue
# Processing Record 37 of Set 3 | kloulklubed
# Processing Record 38 of Set 3 | buriti bravo
# Processing Record 39 of Set 3 | aykhal
# Processing Record 40 of Set 3 | mago
# Processing Record 41 of Set 3 | biak
# Processing Record 42 of Set 3 | aksu
# Processing Record 43 of Set 3 | lagoa
# Processing Record 44 of Set 3 | ahipara
# Processing Record 45 of Set 3 | glace bay
# Processing Record 46 of Set 3 | avarua
# Processing Record 47 of Set 3 | mwinilunga
# Processing Record 48 of Set 3 | deputatskiy
# Processing Record 49 of Set 3 | zvishavane
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | tautira
# Processing Record 2 of Set 4 | ibanda
# Processing Record 3 of Set 4 | porto velho
# Processing Record 4 of Set 4 | goderich
# Processing Record 5 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 4 | kaeo
# Processing Record 7 of Set 4 | torbay
# Processing Record 8 of Set 4 | kachug
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | kamaishi
# Processing Record 11 of Set 4 | reconquista
# Processing Record 12 of Set 4 | sao filipe
# Processing Record 13 of Set 4 | port hedland
# Processing Record 14 of Set 4 | saint-joseph
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | kapaa
# Processing Record 17 of Set 4 | pozo colorado
# Processing Record 18 of Set 4 | geraldton
# Processing Record 19 of Set 4 | sobolevo
# Processing Record 20 of Set 4 | port elizabeth
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | saskylakh
# Processing Record 23 of Set 4 | alyangula
# Processing Record 24 of Set 4 | vung tau
# Processing Record 25 of Set 4 | urengoy
# Processing Record 26 of Set 4 | manbij
# Processing Record 27 of Set 4 | paita
# Processing Record 28 of Set 4 | fremont
# Processing Record 29 of Set 4 | aripuana
# Processing Record 30 of Set 4 | klyuchi
# Processing Record 31 of Set 4 | koumac
# Processing Record 32 of Set 4 | angoche
# Processing Record 33 of Set 4 | machali
# Processing Record 34 of Set 4 | diamantino
# Processing Record 35 of Set 4 | shingu
# Processing Record 36 of Set 4 | uzhur
# Processing Record 37 of Set 4 | canguaretama
# Processing Record 38 of Set 4 | dubai
# Processing Record 39 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 40 of Set 4 | cherdyn
# Processing Record 41 of Set 4 | beloha
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | nelson bay
# Processing Record 44 of Set 4 | bardiyah
# Processing Record 45 of Set 4 | broken hill
# Processing Record 46 of Set 4 | cockburn town
# Processing Record 47 of Set 4 | killybegs
# Processing Record 48 of Set 4 | buala
# Processing Record 49 of Set 4 | victoria
# Processing Record 50 of Set 4 | nuuk
# Processing Record 1 of Set 5 | kattivakkam
# Processing Record 2 of Set 5 | bull savanna
# Processing Record 3 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 5 | katsuura
# Processing Record 5 of Set 5 | vostok
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | lovozero
# Processing Record 9 of Set 5 | tzaneen
# Processing Record 10 of Set 5 | krasnyy chikoy
# Processing Record 11 of Set 5 | alofi
# Processing Record 12 of Set 5 | lerwick
# Processing Record 13 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 5 | luderitz
# Processing Record 15 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 16 of Set 5 | dingle
# Processing Record 17 of Set 5 | mamallapuram
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | butaritari
# Processing Record 20 of Set 5 | funtua
# Processing Record 21 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 5 | pandrup
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | aksehir
# Processing Record 27 of Set 5 | ulladulla
# Processing Record 28 of Set 5 | haines junction
# Processing Record 29 of Set 5 | peterhead
# Processing Record 30 of Set 5 | bekhtery
# Processing Record 31 of Set 5 | cogealac
# Processing Record 32 of Set 5 | broome
# Processing Record 33 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 5 | denpasar
# Processing Record 35 of Set 5 | roseburg
# Processing Record 36 of Set 5 | stromness
# Processing Record 37 of Set 5 | sistranda
# Processing Record 38 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 39 of Set 5 | thompson
# Processing Record 40 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | opole lubelskie
# Processing Record 43 of Set 5 | honningsvag
# Processing Record 44 of Set 5 | banda aceh
# Processing Record 45 of Set 5 | maracas
# Processing Record 46 of Set 5 | egvekinot
# Processing Record 47 of Set 5 | rosetta
# Processing Record 48 of Set 5 | ayagoz
# Processing Record 49 of Set 5 | cedar city
# Processing Record 50 of Set 5 | kenai
# Processing Record 1 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 2 of Set 6 | krutikha
# Processing Record 3 of Set 6 | alihe
# Processing Record 4 of Set 6 | chuy
# Processing Record 5 of Set 6 | bambous virieux
# Processing Record 6 of Set 6 | madang
# Processing Record 7 of Set 6 | conde
# Processing Record 8 of Set 6 | nome
# Processing Record 9 of Set 6 | jumla
# Processing Record 10 of Set 6 | nantucket
# Processing Record 11 of Set 6 | vardo
# Processing Record 12 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 6 | los llanos de aridane
# Processing Record 14 of Set 6 | fortuna
# Processing Record 15 of Set 6 | qaanaaq
# Processing Record 16 of Set 6 | raboso
# Processing Record 17 of Set 6 | san carlos de bariloche
# Processing Record 18 of Set 6 | sechura
# Processing Record 19 of Set 6 | yar-sale
# Processing Record 20 of Set 6 | maragogi
# Processing Record 21 of Set 6 | eyl
# Processing Record 22 of Set 6 | sao felix do xingu
# Processing Record 23 of Set 6 | coulihaut
# City not found. Skipping...
# Processing Record 24 of Set 6 | ayan
# Processing Record 25 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 6 | salinopolis
# Processing Record 27 of Set 6 | darnah
# Processing Record 28 of Set 6 | aswan
# Processing Record 29 of Set 6 | orlik
# Processing Record 30 of Set 6 | la orilla
# Processing Record 31 of Set 6 | ishigaki
# Processing Record 32 of Set 6 | porto seguro
# Processing Record 33 of Set 6 | santa fe
# Processing Record 34 of Set 6 | hami
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | purpe
# Processing Record 37 of Set 6 | podporozhye
# Processing Record 38 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 6 | saint george
# Processing Record 40 of Set 6 | baykit
# Processing Record 41 of Set 6 | wuwei
# Processing Record 42 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 6 | portland
# Processing Record 44 of Set 6 | barrow
# Processing Record 45 of Set 6 | marawi
# Processing Record 46 of Set 6 | mindelo
# Processing Record 47 of Set 6 | caucaia
# Processing Record 48 of Set 6 | maputo
# Processing Record 49 of Set 6 | waddan
# Processing Record 50 of Set 6 | norman wells
# Processing Record 1 of Set 7 | cidreira
# Processing Record 2 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 7 | borovoy
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | newtownards
# Processing Record 6 of Set 7 | kropachevo
# Processing Record 7 of Set 7 | new norfolk
# Processing Record 8 of Set 7 | mar del plata
# Processing Record 9 of Set 7 | carnarvon
# Processing Record 10 of Set 7 | smirnykh
# Processing Record 11 of Set 7 | santiago del estero
# Processing Record 12 of Set 7 | sfantu gheorghe
# Processing Record 13 of Set 7 | mokhsogollokh
# Processing Record 14 of Set 7 | port hawkesbury
# Processing Record 15 of Set 7 | tartus
# Processing Record 16 of Set 7 | rantepao
# Processing Record 17 of Set 7 | sorland
# Processing Record 18 of Set 7 | badou
# Processing Record 19 of Set 7 | merauke
# Processing Record 20 of Set 7 | newton stewart
# Processing Record 21 of Set 7 | okakarara
# Processing Record 22 of Set 7 | turukhansk
# Processing Record 23 of Set 7 | natal
# Processing Record 24 of Set 7 | carroll
# Processing Record 25 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 7 | leningradskiy
# Processing Record 27 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 7 | ossora
# Processing Record 29 of Set 7 | saint-pierre
# Processing Record 30 of Set 7 | roma
# Processing Record 31 of Set 7 | campechuela
# Processing Record 32 of Set 7 | acapulco
# Processing Record 33 of Set 7 | walla walla
# Processing Record 34 of Set 7 | vagur
# Processing Record 35 of Set 7 | te anau
# Processing Record 36 of Set 7 | maunabo
# Processing Record 37 of Set 7 | ronneby
# Processing Record 38 of Set 7 | bastia
# Processing Record 39 of Set 7 | chapais
# Processing Record 40 of Set 7 | rosita
# Processing Record 41 of Set 7 | radcliff
# Processing Record 42 of Set 7 | olinda
# Processing Record 43 of Set 7 | sol-iletsk
# Processing Record 44 of Set 7 | mayo
# Processing Record 45 of Set 7 | high level
# Processing Record 46 of Set 7 | yumen
# Processing Record 47 of Set 7 | monte alegre
# Processing Record 48 of Set 7 | ancud
# Processing Record 49 of Set 7 | port hardy
# Processing Record 50 of Set 7 | hohhot
# Processing Record 1 of Set 8 | luba
# Processing Record 2 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 8 | barreiras
# Processing Record 4 of Set 8 | vila velha
# Processing Record 5 of Set 8 | vladesti
# Processing Record 6 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 8 | dwarka
# Processing Record 8 of Set 8 | xiamen
# Processing Record 9 of Set 8 | leh
# Processing Record 10 of Set 8 | beringovskiy
# Processing Record 11 of Set 8 | havre-saint-pierre
# Processing Record 12 of Set 8 | garissa
# Processing Record 13 of Set 8 | cayenne
# Processing Record 14 of Set 8 | shakawe
# Processing Record 15 of Set 8 | baturaja
# Processing Record 16 of Set 8 | jibuti
# Processing Record 17 of Set 8 | bereda
# Processing Record 18 of Set 8 | samarai
# Processing Record 19 of Set 8 | ruian
# City not found. Skipping...
# Processing Record 20 of Set 8 | takaungu
# Processing Record 21 of Set 8 | senneterre
# Processing Record 22 of Set 8 | lompoc
# Processing Record 23 of Set 8 | wanning
# Processing Record 24 of Set 8 | hofn
# Processing Record 25 of Set 8 | klaksvik
# Processing Record 26 of Set 8 | olafsvik
# Processing Record 27 of Set 8 | luena
# Processing Record 28 of Set 8 | ginir
# Processing Record 29 of Set 8 | port moresby
# Processing Record 30 of Set 8 | chernyshevskiy
# Processing Record 31 of Set 8 | taoudenni
# Processing Record 32 of Set 8 | wamba
# Processing Record 33 of Set 8 | marzuq
# Processing Record 34 of Set 8 | parabel
# Processing Record 35 of Set 8 | san pedro
# Processing Record 36 of Set 8 | malko tarnovo
# Processing Record 37 of Set 8 | bonito
# Processing Record 38 of Set 8 | khani
# Processing Record 39 of Set 8 | sabha
# Processing Record 40 of Set 8 | demba
# Processing Record 41 of Set 8 | trinidad
# Processing Record 42 of Set 8 | san cristobal
# Processing Record 43 of Set 8 | okhotsk
# Processing Record 44 of Set 8 | pangoa
# Processing Record 45 of Set 8 | salalah
# Processing Record 46 of Set 8 | zyryanka
# Processing Record 47 of Set 8 | kashan
# Processing Record 48 of Set 8 | antalaha
# Processing Record 49 of Set 8 | kiunga
# Processing Record 50 of Set 8 | fengkou
# Processing Record 1 of Set 9 | santiago
# Processing Record 2 of Set 9 | lima
# Processing Record 3 of Set 9 | umm lajj
# Processing Record 4 of Set 9 | lorca
# Processing Record 5 of Set 9 | zhezkazgan
# Processing Record 6 of Set 9 | katherine
# Processing Record 7 of Set 9 | san patricio
# Processing Record 8 of Set 9 | boralday
# Processing Record 9 of Set 9 | campos altos
# Processing Record 10 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 9 | tura
# Processing Record 12 of Set 9 | yulara
# Processing Record 13 of Set 9 | san andres
# Processing Record 14 of Set 9 | biltine
# Processing Record 15 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 9 | caravelas
# Processing Record 18 of Set 9 | cherskiy
# Processing Record 19 of Set 9 | moorhead
# Processing Record 20 of Set 9 | north bend
# Processing Record 21 of Set 9 | anadyr
# Processing Record 22 of Set 9 | nakhon nayok
# Processing Record 23 of Set 9 | revda
# Processing Record 24 of Set 9 | karpogory
# Processing Record 25 of Set 9 | catamarca
# Processing Record 26 of Set 9 | sinnamary
# Processing Record 27 of Set 9 | ubinskoye
# Processing Record 28 of Set 9 | kautokeino
# Processing Record 29 of Set 9 | rorvik
# Processing Record 30 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 9 | prince rupert
# Processing Record 32 of Set 9 | talah
# City not found. Skipping...
# Processing Record 33 of Set 9 | san quintin
# Processing Record 34 of Set 9 | half moon bay
# Processing Record 35 of Set 9 | gat
# Processing Record 36 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 9 | isiro
# Processing Record 38 of Set 9 | graaff-reinet
# Processing Record 39 of Set 9 | panaba
# Processing Record 40 of Set 9 | coahuayana
# Processing Record 41 of Set 9 | husavik
# Processing Record 42 of Set 9 | yushan
# Processing Record 43 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 44 of Set 9 | srednekolymsk
# Processing Record 45 of Set 9 | naze
# Processing Record 46 of Set 9 | balikpapan
# Processing Record 47 of Set 9 | novyy urengoy
# Processing Record 48 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 9 | superior
# Processing Record 50 of Set 9 | shizuishan
# Processing Record 1 of Set 10 | seoul
# Processing Record 2 of Set 10 | tucuman
# Processing Record 3 of Set 10 | ahuimanu
# Processing Record 4 of Set 10 | rawson
# Processing Record 5 of Set 10 | nanortalik
# Processing Record 6 of Set 10 | kangaatsiaq
# Processing Record 7 of Set 10 | sola
# Processing Record 8 of Set 10 | glens falls
# Processing Record 9 of Set 10 | ca mau
# Processing Record 10 of Set 10 | dumai
# Processing Record 11 of Set 10 | itaobim
# Processing Record 12 of Set 10 | selma
# Processing Record 13 of Set 10 | warmbad
# Processing Record 14 of Set 10 | ruidoso
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | mehamn
# Processing Record 17 of Set 10 | atbasar
# Processing Record 18 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 10 | souillac
# Processing Record 20 of Set 10 | ahome
# Processing Record 21 of Set 10 | toba
# Processing Record 22 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 23 of Set 10 | gawler
# Processing Record 24 of Set 10 | ngaoundere
# Processing Record 25 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 10 | vila franca do campo
# Processing Record 27 of Set 10 | mubi
# Processing Record 28 of Set 10 | kiruna
# Processing Record 29 of Set 10 | pipri
# Processing Record 30 of Set 10 | hovd
# Processing Record 31 of Set 10 | ambilobe
# Processing Record 32 of Set 10 | amahai
# Processing Record 33 of Set 10 | qaqortoq
# Processing Record 34 of Set 10 | khandyga
# Processing Record 35 of Set 10 | ust-kuyga
# Processing Record 36 of Set 10 | de aar
# Processing Record 37 of Set 10 | blagoveshchenka
# Processing Record 38 of Set 10 | lorengau
# Processing Record 39 of Set 10 | labuan
# Processing Record 40 of Set 10 | grand gaube
# Processing Record 41 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 42 of Set 10 | bilibino
# Processing Record 43 of Set 10 | flinders
# Processing Record 44 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 10 | teguise
# Processing Record 46 of Set 10 | rapid valley
# Processing Record 47 of Set 10 | srandakan
# Processing Record 48 of Set 10 | tilichiki
# Processing Record 49 of Set 10 | cap-aux-meules
# Processing Record 50 of Set 10 | toccoa
# Processing Record 1 of Set 11 | havelock
# Processing Record 2 of Set 11 | ewa beach
# Processing Record 3 of Set 11 | yamada
# Processing Record 4 of Set 11 | tessalit
# Processing Record 5 of Set 11 | ghanzi
# Processing Record 6 of Set 11 | pilar
# Processing Record 7 of Set 11 | omboue
# Processing Record 8 of Set 11 | moerai
# Processing Record 9 of Set 11 | aiantion
# City not found. Skipping...
# Processing Record 10 of Set 11 | channel-port aux basques
# Processing Record 11 of Set 11 | sao raimundo das mangabeiras
# Processing Record 12 of Set 11 | namibe
# Processing Record 13 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 11 | isangel
# Processing Record 15 of Set 11 | muros
# Processing Record 16 of Set 11 | ola
# Processing Record 17 of Set 11 | kankon
# Processing Record 18 of Set 11 | entre rios
# Processing Record 19 of Set 11 | tatvan
# Processing Record 20 of Set 11 | bodden town
# Processing Record 21 of Set 11 | nishihara
# Processing Record 22 of Set 11 | kurilsk
# Processing Record 23 of Set 11 | zhigansk
# Processing Record 24 of Set 11 | atar
# Processing Record 25 of Set 11 | raudeberg
# Processing Record 26 of Set 11 | presidente medici
# Processing Record 27 of Set 11 | champerico
# Processing Record 28 of Set 11 | buraydah
# Processing Record 29 of Set 11 | hengshui
# Processing Record 30 of Set 11 | cetraro
# Processing Record 31 of Set 11 | mattru
# Processing Record 32 of Set 11 | baracoa
# Processing Record 33 of Set 11 | moron
# Processing Record 34 of Set 11 | kibala
# Processing Record 35 of Set 11 | belmonte
# Processing Record 36 of Set 11 | kalmunai
# Processing Record 37 of Set 11 | turhal
# Processing Record 38 of Set 11 | mandali
# Processing Record 39 of Set 11 | semirom
# Processing Record 40 of Set 11 | puerto maldonado
# Processing Record 41 of Set 11 | sohag
# Processing Record 42 of Set 11 | himora
# City not found. Skipping...
# Processing Record 43 of Set 11 | xinye
# Processing Record 44 of Set 11 | cowra
# Processing Record 45 of Set 11 | adrar
# Processing Record 46 of Set 11 | jalingo
# Processing Record 47 of Set 11 | sale
# Processing Record 48 of Set 11 | omsukchan
# Processing Record 49 of Set 11 | santa cruz
# Processing Record 50 of Set 11 | iqaluit
# Processing Record 1 of Set 12 | acajutla
# Processing Record 2 of Set 12 | kishtwar
# Processing Record 3 of Set 12 | dunedin
# Processing Record 4 of Set 12 | sawtell
# Processing Record 5 of Set 12 | tezu
# Processing Record 6 of Set 12 | sitka
# Processing Record 7 of Set 12 | ibra
# Processing Record 8 of Set 12 | ouallam
# Processing Record 9 of Set 12 | juruti
# Processing Record 10 of Set 12 | nefteyugansk
# Processing Record 11 of Set 12 | lantawan
# Processing Record 12 of Set 12 | axim
# Processing Record 13 of Set 12 | pacifica
# Processing Record 14 of Set 12 | kindu
# Processing Record 15 of Set 12 | kamloops
# Processing Record 16 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 17 of Set 12 | yatou
# Processing Record 18 of Set 12 | indramayu
# Processing Record 19 of Set 12 | barranca
# Processing Record 20 of Set 12 | kavaratti
# Processing Record 21 of Set 12 | iquira
# Processing Record 22 of Set 12 | boddam
# Processing Record 23 of Set 12 | gambela
# Processing Record 24 of Set 12 | matamoros
# Processing Record 25 of Set 12 | sento se
# City not found. Skipping...
# Processing Record 26 of Set 12 | krasnoselkup
# Processing Record 27 of Set 12 | antigonish
# Processing Record 28 of Set 12 | mitchell
# Processing Record 29 of Set 12 | troitsko-pechorsk
# Processing Record 30 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 12 | muravlenko
# Processing Record 32 of Set 12 | owando
# Processing Record 33 of Set 12 | lakeway
# Processing Record 34 of Set 12 | port-gentil
# Processing Record 35 of Set 12 | gucheng
# Processing Record 36 of Set 12 | byron bay
# Processing Record 37 of Set 12 | safford
# Processing Record 38 of Set 12 | big spring
# Processing Record 39 of Set 12 | vaitape
# Processing Record 40 of Set 12 | bubaque
# Processing Record 41 of Set 12 | manavalakurichi
# Processing Record 42 of Set 12 | poum
# Processing Record 43 of Set 12 | basudebpur
# Processing Record 44 of Set 12 | mucurapo
# Processing Record 45 of Set 12 | dori
# Processing Record 46 of Set 12 | mackenzie
# Processing Record 47 of Set 12 | bonthe
# Processing Record 48 of Set 12 | nagato
# Processing Record 49 of Set 12 | belyye berega
# Processing Record 50 of Set 12 | mnogovershinnyy
# Processing Record 1 of Set 13 | vila
# Processing Record 2 of Set 13 | jimeta
# Processing Record 3 of Set 13 | brownsville
# Processing Record 4 of Set 13 | takanabe
# Processing Record 5 of Set 13 | tuatapere
# Processing Record 6 of Set 13 | kodinar
# Processing Record 7 of Set 13 | tiarei
# Processing Record 8 of Set 13 | bend
# Processing Record 9 of Set 13 | aushiger
# Processing Record 10 of Set 13 | keuruu
# Processing Record 11 of Set 13 | eureka
# Processing Record 12 of Set 13 | itatinga
# Processing Record 13 of Set 13 | riyadh
# Processing Record 14 of Set 13 | miri
# Processing Record 15 of Set 13 | sergeyevka
# Processing Record 16 of Set 13 | chumikan
# Processing Record 17 of Set 13 | camacari
# Processing Record 18 of Set 13 | ajdabiya
# Processing Record 19 of Set 13 | zaysan
# Processing Record 20 of Set 13 | katubao
# Processing Record 21 of Set 13 | bowen
# Processing Record 22 of Set 13 | kapit
# Processing Record 23 of Set 13 | guerrero negro
# Processing Record 24 of Set 13 | svetlyy
# Processing Record 25 of Set 13 | karratha
# Processing Record 26 of Set 13 | henties bay
# Processing Record 27 of Set 13 | san rafael
# Processing Record 28 of Set 13 | mahibadhoo
# Processing Record 29 of Set 13 | yurimaguas
# Processing Record 30 of Set 13 | zheshart
# Processing Record 31 of Set 13 | birin
# Processing Record 32 of Set 13 | kalakamati
# Processing Record 33 of Set 13 | black river
# Processing Record 34 of Set 13 | smithers
# Processing Record 35 of Set 13 | brae
# Processing Record 36 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 13 | whitehorse
# Processing Record 39 of Set 13 | conceicao do mato dentro
# Processing Record 40 of Set 13 | jammalamadugu
# Processing Record 41 of Set 13 | makakilo city
# Processing Record 42 of Set 13 | paamiut
# Processing Record 43 of Set 13 | atambua
# Processing Record 44 of Set 13 | rio gallegos
# Processing Record 45 of Set 13 | tateyama
# Processing Record 46 of Set 13 | det udom
# Processing Record 47 of Set 13 | netrakona
# Processing Record 48 of Set 13 | bratsk
# Processing Record 49 of Set 13 | yertsevo
# Processing Record 50 of Set 13 | grindavik
# Processing Record 1 of Set 14 | palmer
# Processing Record 2 of Set 14 | tornio
# Processing Record 3 of Set 14 | svetlaya
# Processing Record 4 of Set 14 | swift current
# Processing Record 5 of Set 14 | sangmelima
# Processing Record 6 of Set 14 | kahului
# Processing Record 7 of Set 14 | traverse city
# Processing Record 8 of Set 14 | amli
# Processing Record 9 of Set 14 | coxim
# Processing Record 10 of Set 14 | campo grande
# Processing Record 11 of Set 14 | shelburne
# Processing Record 12 of Set 14 | puerto leguizamo
# Processing Record 13 of Set 14 | cabedelo
# Processing Record 14 of Set 14 | lakatoro
# Processing Record 15 of Set 14 | hefei
# Processing Record 16 of Set 14 | marrakesh
# Processing Record 17 of Set 14 | kemijarvi
# Processing Record 18 of Set 14 | lavrentiya
# Processing Record 19 of Set 14 | swan hill
# Processing Record 20 of Set 14 | les cayes
# Processing Record 21 of Set 14 | aanekoski
# Processing Record 22 of Set 14 | wattegama
# Processing Record 23 of Set 14 | tommot
# Processing Record 24 of Set 14 | gornopravdinsk
# Processing Record 25 of Set 14 | elizabeth city
# Processing Record 26 of Set 14 | dryden
# Processing Record 27 of Set 14 | talcahuano
# Processing Record 28 of Set 14 | ojinaga
# Processing Record 29 of Set 14 | hirara
# Processing Record 30 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 14 | piacabucu
# Processing Record 32 of Set 14 | homer
# Processing Record 33 of Set 14 | andra
# Processing Record 34 of Set 14 | isla mujeres
# Processing Record 35 of Set 14 | vidim
# Processing Record 36 of Set 14 | gandai
# Processing Record 37 of Set 14 | setermoen
# Processing Record 38 of Set 14 | pandaria
# Processing Record 39 of Set 14 | kilindoni
# Processing Record 40 of Set 14 | porto belo
# Processing Record 41 of Set 14 | gazojak
# Processing Record 42 of Set 14 | abastumani
# Processing Record 43 of Set 14 | menongue
# Processing Record 44 of Set 14 | mogadishu
# Processing Record 45 of Set 14 | manakara
# Processing Record 46 of Set 14 | pierre
# Processing Record 47 of Set 14 | waingapu
# Processing Record 48 of Set 14 | laurel
# Processing Record 49 of Set 14 | ocean city
# Processing Record 50 of Set 14 | puerto baquerizo moreno
# Processing Record 1 of Set 15 | rongcheng
# Processing Record 2 of Set 15 | ekimchan
# Processing Record 3 of Set 15 | koubia
# Processing Record 4 of Set 15 | festus
# Processing Record 5 of Set 15 | tecoanapa
# Processing Record 6 of Set 15 | richards bay
# Processing Record 7 of Set 15 | san felipe
# Processing Record 8 of Set 15 | kedrovyy
# Processing Record 9 of Set 15 | taft
# Processing Record 10 of Set 15 | bom jesus
# Processing Record 11 of Set 15 | vanimo
# Processing Record 12 of Set 15 | swan river
# Processing Record 13 of Set 15 | besancon
# Processing Record 14 of Set 15 | aljezur
# Processing Record 15 of Set 15 | bulawayo
# Processing Record 16 of Set 15 | vikindu
# Processing Record 17 of Set 15 | nhulunbuy
# Processing Record 18 of Set 15 | rocha
# Processing Record 19 of Set 15 | weligama
# Processing Record 20 of Set 15 | shaoguan
# Processing Record 21 of Set 15 | astara
# Processing Record 22 of Set 15 | thunder bay
# Processing Record 23 of Set 15 | ban dung
# Processing Record 24 of Set 15 | avera
# Processing Record 25 of Set 15 | lesogorsk
# Processing Record 26 of Set 15 | kodinsk
# Processing Record 27 of Set 15 | chiredzi
# Processing Record 28 of Set 15 | bathsheba
# Processing Record 29 of Set 15 | kidal
# Processing Record 30 of Set 15 | wukari
# Processing Record 31 of Set 15 | comodoro rivadavia
# Processing Record 32 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 33 of Set 15 | lexington
# Processing Record 34 of Set 15 | maldonado
# Processing Record 35 of Set 15 | grand-lahou
# Processing Record 36 of Set 15 | quatre cocos
# Processing Record 37 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 15 | batemans bay
# Processing Record 39 of Set 15 | katangli
# Processing Record 40 of Set 15 | kunming
# Processing Record 41 of Set 15 | hambantota
# Processing Record 42 of Set 15 | oranjemund
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Lebu      CL -37.6167  -73.6500     57.97        90           1
# 1           Bluff      NZ -46.6000  168.3333     57.79        58          48
# 2         Iquitos      PE  -3.7481  -73.2472     77.04        94          75
# 3             Fez      MA  34.0372   -4.9998     44.71        60          70
# 4         Mataura      NZ -46.1927  168.8643     57.47        38          47
# 5          Bethel      US  41.3712  -73.4140     21.56        60           1
# 6  Severo-Kurilsk      RU  50.6789  156.1250     26.44        67          88
# 7     Balaipungut      ID   1.0500  101.2833     77.41        74         100
# 8       Abu Kamal      SY  34.4506   40.9171     46.98        62          59
# 9            Leua      SK  48.2156   18.6071     36.50        93         100
#
#    Wind Speed Current Description
# 0        8.77           clear sky
# 1       12.17    scattered clouds
# 2        1.14       broken clouds
# 3        3.44       broken clouds
# 4        6.93    scattered clouds
# 5        4.81           clear sky
# 6       27.45     overcast clouds
# 7        2.68     overcast clouds
# 8       16.22       broken clouds
# 9        6.46     overcast clouds

# %%
#Re-order columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Lebu      CL -37.6167  -73.6500     57.97        90           1
# 1           Bluff      NZ -46.6000  168.3333     57.79        58          48
# 2         Iquitos      PE  -3.7481  -73.2472     77.04        94          75
# 3             Fez      MA  34.0372   -4.9998     44.71        60          70
# 4         Mataura      NZ -46.1927  168.8643     57.47        38          47
# 5          Bethel      US  41.3712  -73.4140     21.56        60           1
# 6  Severo-Kurilsk      RU  50.6789  156.1250     26.44        67          88
# 7     Balaipungut      ID   1.0500  101.2833     77.41        74         100
# 8       Abu Kamal      SY  34.4506   40.9171     46.98        62          59
# 9            Leua      SK  48.2156   18.6071     36.50        93         100
#
#    Wind Speed Current Description
# 0        8.77           clear sky
# 1       12.17    scattered clouds
# 2        1.14       broken clouds
# 3        3.44       broken clouds
# 4        6.93    scattered clouds
# 5        4.81           clear sky
# 6       27.45     overcast clouds
# 7        2.68     overcast clouds
# 8       16.22       broken clouds
# 9        6.46     overcast clouds

# %%
# Create the output file (csv).
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a csv.
city_data_df.to_csv(output_data_file, index_label="City_ID")
